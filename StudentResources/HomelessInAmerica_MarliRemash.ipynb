# %% [markdown]
# ## Homeless In America
# DataSet from: https://jupyter.grinnell.edu/user/remashma/notebooks/HomelessInAmerica_MarliRemash.ipynb

# %%
# %matplotlib inline

import pandas as pd
import statistics as st
import matplotlib
import numpy as np

matplotlib.style.use('ggplot')

filename_2016 = "https://raw.githubusercontent.com/mashmouse/DataScienceForSocialGoodJupyterNotebooks/master/Data/Homeless-by-State_2016.csv"
filename_2015 = "https://raw.githubusercontent.com/mashmouse/DataScienceForSocialGoodJupyterNotebooks/master/Data/Homeless-by-State_2016.csv"

data_2016 = pd.read_csv(filename_2016)
data_2015 = pd.read_csv(filename_2015)

df16 = pd.DataFrame(data_2016)
df15 = pd.DataFrame(data_2015)

#print(df16.index)
#print(df16.columns)
#print(df16['Total Homeless, 2016'][:54])
#df16.plot.pie(y='Total Homeless, 2016', index=df16['State'])

df16[:54].plot.bar(x='State', y='Number of CoCs', figsize=(20, 15))

df16[:54].plot.pie(y='Number of CoCs')
